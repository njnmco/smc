# %%
! pip install /home/nfultz/projects/smc/
# Out:
# Processing /home/nfultz/projects/smc
# Requirement already satisfied: numpy in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from eonacs==1.0.0) (1.21.0)
# Requirement already satisfied: pacmap in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from eonacs==1.0.0) (0.6.3)
# Requirement already satisfied: transformers in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from eonacs==1.0.0) (4.18.0)
# Requirement already satisfied: annoy>=1.11 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from pacmap->eonacs==1.0.0) (1.17.0)
# Requirement already satisfied: scikit-learn>=0.20 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from pacmap->eonacs==1.0.0) (1.0.2)
# Requirement already satisfied: numba>=0.50 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from pacmap->eonacs==1.0.0) (0.55.1)
# Requirement already satisfied: sacremoses in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from transformers->eonacs==1.0.0) (0.0.49)
# Requirement already satisfied: requests in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from transformers->eonacs==1.0.0) (2.27.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from transformers->eonacs==1.0.0) (2022.3.15)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from transformers->eonacs==1.0.0) (0.5.1)
# Requirement already satisfied: filelock in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from transformers->eonacs==1.0.0) (3.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from transformers->eonacs==1.0.0) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from transformers->eonacs==1.0.0) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from transformers->eonacs==1.0.0) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from transformers->eonacs==1.0.0) (4.64.0)
# Requirement already satisfied: joblib>=0.11 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from scikit-learn>=0.20->pacmap->eonacs==1.0.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from scikit-learn>=0.20->pacmap->eonacs==1.0.0) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from scikit-learn>=0.20->pacmap->eonacs==1.0.0) (1.8.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from numba>=0.50->pacmap->eonacs==1.0.0) (0.38.0)
# Requirement already satisfied: setuptools in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from numba>=0.50->pacmap->eonacs==1.0.0) (44.0.0)
# Requirement already satisfied: six in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from sacremoses->transformers->eonacs==1.0.0) (1.16.0)
# Requirement already satisfied: click in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from sacremoses->transformers->eonacs==1.0.0) (8.1.2)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from requests->transformers->eonacs==1.0.0) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from requests->transformers->eonacs==1.0.0) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from requests->transformers->eonacs==1.0.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from requests->transformers->eonacs==1.0.0) (1.26.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers->eonacs==1.0.0) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/nfultz/projects/smc/venv/lib/python3.8/site-packages (from packaging>=20.0->transformers->eonacs==1.0.0) (3.0.8)
# Building wheels for collected packages: eonacs
#   Building wheel for eonacs (setup.py) ... done
#   Created wheel for eonacs: filename=eonacs-1.0.0-py3-none-any.whl size=4630 sha256=592b2733a275e7954173cf3cb78aca737c299c8dad6522c4c80870c16eee2e09
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hk_4y_6o/wheels/a8/ed/04/34c7726893d8b4448376a099adcf05036183a5e1272bb3d481
# Successfully built eonacs
# Installing collected packages: eonacs
#   Attempting uninstall: eonacs
#     Found existing installation: eonacs 1.0.0
#     Uninstalling eonacs-1.0.0:
#       Successfully uninstalled eonacs-1.0.0
# Successfully installed eonacs-1.0.0

# %%
import pacmap

# %%
import eonacs

# %%
import numpy as np
import pandas as pd

# %%
import multiprocessing
#multiprocessing.set_start_method("spawn")

# %%
tasks, hyper_e = pd.read_pickle("../../data/tasks_dbert_hyper_e.pkl.gz")

# %%
tasks.head()
# Out:
#   soc                                               text
# 0  11  Direct or coordinate an organization's financi...
# 1  11  Appoint department heads or managers and assig...
# 2  11  Analyze operations to evaluate performance of ...
# 3  11  Direct, plan, or implement policies, objective...
# 4  11  Prepare budgets for approval, including those ...

# %% [markdown]
# # hyperopt

# %%
import hyperopt
from hyperopt import hp, space_eval, fmin, Trials, pyll

# %% [markdown]
#     n_components: int, default=2
#         Dimensions of the embedded space. We recommend to use 2 or 3.
#     n_neighbors: int, default=10
#         Number of neighbors considered for nearest neighbor pairs for local structure preservation.
#     MN_ratio: float, default=0.5
#         Ratio of mid near pairs to nearest neighbor pairs (e.g. n_neighbors=10, MN_ratio=0.5 --> 5 Mid near pairs)
#         Mid near pairs are used for global structure preservation.
#     FP_ratio: float, default=2.0
#         Ratio of further pairs to nearest neighbor pairs (e.g. n_neighbors=10, FP_ratio=2 --> 20 Further pairs)
#         Further pairs are used for both local and global structure preservation.

# %%
t = pd.read_pickle("../data/hyperopt.pkl") # Trials()

# %%
best = fmin(a_trial, space, hyperopt.tpe.suggest, len(t) + 100, trials=t)
pd.to_pickle(t, "../data/hyperopt.pkl")
best
# Out:
# 100%|█| 1600/1600 [9:31:21<00:00, 342.82s/trial, best loss: 0.24082587306528885]
# {'lr': 0.15419080348508754,
#  'n_buckets': 704.0,
#  'n_components': 3.0,
#  'n_far': 52.0,
#  'n_mid': 16.0,
#  'n_near': 60.0}

# %% [markdown]
# best
# {'lr': 1.261663829815629,
#  'n_buckets': 304.0,
#  'n_components': 10.0,
#  'n_far': 47.0,
#  'n_mid': 3.0,
#  'n_near': 60.0}

# %% [markdown]
# best
# {'lr': 1.3523696137748484,
#  'n_buckets': 748.0,
#  'n_components': 3.0,
#  'n_far': 46.0,
#  'n_mid': 5.0,
#  'n_near': 60.0}

# %% [markdown]
# best
# {'lr': 1.350658397893707,
#  'n_buckets': 960.0,
#  'n_components': 3.0,
#  'n_far': 58.0,
#  'n_mid': 15.0,
#  'n_near': 56.0}

# %% [markdown]
# best {'lr': 1.350658397893707,
#  'n_buckets': 960.0,
#  'n_components': 3.0,
#  'n_far': 58.0,
#  'n_mid': 15.0,
#  'n_near': 56.0}

# %% [markdown]
# {'lr': 0.20118169453108514,
#  'n_buckets': 804.0,
#  'n_components': 3.0,
#  'n_far': 57.0,
#  'n_mid': 15.0,
#  'n_near': 58.0}

# %%
import hyperopt.plotting

# %%
hyperopt.plotting.main_plot_history(t)
# Out:
# avg best error: 0.24177234245967139

# %%
hyperopt.plotting.main_plot_vars(t)
# Out:
# finite loss range 0.24177234245967139 0.5235062415129984 -0.7582276575403286

# %%
hyperopt.plotting.main_plot_histogram(t)
# Out:
# Showing Histogram of 640 jobs
